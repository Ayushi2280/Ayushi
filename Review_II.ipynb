# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushi2280/The-WallStreet-Mogul/blob/master/Review_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yahoo_fin --upgrade

# %%
pip install requests_html

# %%
import yahoo_fin.stock_info as si
import pandas as pd
import numpy as np

# %%
stock_list = ['ADANIPORTS.NS','ARVIND.NS', 'ASIANPAINT.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BAJAJFINSV.NS', 'BHARTIARTL.NS', 'BPCL.NS', 'BRITANNIA.NS','CIPLA.NS', 'COALINDIA.NS', 'DIVISLAB.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'GILLETTE.NS', 'GOKEX.NS', 'GRASIM.NS', 'HCLTECH.NS', 'HDFC.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS', 'HINDUNILVR.NS', 'IBREALEST.NS', 'ICICIBANK.NS', 'INDUSINDBK.NS', 'INFY.NS', 'IOC.NS',  'ITC.NS', 'JSWSTEEL.NS', 'KOTAKBANK.NS', 'LT.NS', 'M&M.NS', 'MARUTI.NS', 'NESTLEIND.NS', 'NTPC.NS', 'ONGC.NS', 'POWERGRID.NS', 'RELIANCE.NS', 'SBIN.NS', 'SBILIFE.NS', 'SHREECEM.NS', 'SUNPHARMA.NS', 'TATAMOTORS.NS', 'TATASTEEL.NS',  'TCS.NS', 'TATACONSUM.NS', 'TECHM.NS', 'TITAN.NS', 'ULTRACEMCO.NS', 'UPL.NS','WIPRO.NS']

# %%
dow_stats = {}
for ticker in stock_list:
    temp = si.get_stats_valuation(ticker)
    temp = temp.iloc[:,:2]
    temp.columns = ["Attribute", "Recent"]
    dow_stats[ticker] = temp
dow_stats
# Out:
# {'ADANIPORTS.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.51T
#  1           Enterprise Value  1.83T
#  2               Trailing P/E  29.39
#  3                Forward P/E  19.57
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   9.80
#  6           Price/Book (mrq)   4.87
#  7   Enterprise Value/Revenue  11.93
#  8    Enterprise Value/EBITDA  16.68,
#  'ARVIND.NS':                    Attribute  Recent
#  0      Market Cap (intraday)  29.24B
#  1           Enterprise Value  48.03B
#  2               Trailing P/E   18.70
#  3                Forward P/E     NaN
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)    0.45
#  6           Price/Book (mrq)    1.05
#  7   Enterprise Value/Revenue    0.73
#  8    Enterprise Value/EBITDA    6.59,
#  'ASIANPAINT.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.98T
#  1           Enterprise Value  2.96T
#  2               Trailing P/E  91.65
#  3                Forward P/E  71.94
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)  11.51
#  6           Price/Book (mrq)  23.86
#  7   Enterprise Value/Revenue  11.44
#  8    Enterprise Value/EBITDA  55.24,
#  'AXISBANK.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.06T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  20.61
#  3                Forward P/E  11.92
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.44
#  6           Price/Book (mrq)   1.88
#  7   Enterprise Value/Revenue    NaN
#  8    Enterprise Value/EBITDA    NaN,
#  'BAJAJ-AUTO.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  941.67B
#  1           Enterprise Value  870.46B
#  2               Trailing P/E    14.51
#  3                Forward P/E    13.61
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     2.86
#  6           Price/Book (mrq)     3.48
#  7   Enterprise Value/Revenue     2.65
#  8    Enterprise Value/EBITDA    10.44,
#  'BAJAJFINSV.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.69T
#  1           Enterprise Value  3.76T
#  2               Trailing P/E  63.65
#  3                Forward P/E    NaN
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.63
#  6           Price/Book (mrq)   7.10
#  7   Enterprise Value/Revenue   6.48
#  8    Enterprise Value/EBITDA    NaN,
#  'BAJFINANCE.NS':                    Attribute Recent
#  0      Market Cap (intraday)  4.27T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  86.18
#  3                Forward P/E  43.48
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)  25.18
#  6           Price/Book (mrq)  10.94
#  7   Enterprise Value/Revenue  10.89
#  8    Enterprise Value/EBITDA    NaN,
#  'BHARTIARTL.NS':                    Attribute Recent
#  0      Market Cap (intraday)  4.21T
#  1           Enterprise Value  5.62T
#  2               Trailing P/E    NaN
#  3                Forward P/E  43.67
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   3.71
#  6           Price/Book (mrq)   6.99
#  7   Enterprise Value/Revenue   5.23
#  8    Enterprise Value/EBITDA  11.94,
#  'BPCL.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  837.11B
#  1           Enterprise Value    1.24T
#  2               Trailing P/E     4.37
#  3                Forward P/E    12.79
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     0.27
#  6           Price/Book (mrq)     1.73
#  7   Enterprise Value/Revenue     0.43
#  8    Enterprise Value/EBITDA     4.14,
#  'BRITANNIA.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  856.48B
#  1           Enterprise Value  872.76B
#  2               Trailing P/E    53.72
#  3                Forward P/E    45.87
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     6.56
#  6           Price/Book (mrq)    47.47
#  7   Enterprise Value/Revenue     6.69
#  8    Enterprise Value/EBITDA    35.12,
#  'CIPLA.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  724.41B
#  1           Enterprise Value  695.21B
#  2               Trailing P/E    28.02
#  3                Forward P/E    22.73
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     3.50
#  6           Price/Book (mrq)     3.73
#  7   Enterprise Value/Revenue     3.35
#  8    Enterprise Value/EBITDA    14.67,
#  'COALINDIA.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  984.50B
#  1           Enterprise Value  704.39B
#  2               Trailing P/E     7.14
#  3                Forward P/E     4.92
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     1.08
#  6           Price/Book (mrq)     2.44
#  7   Enterprise Value/Revenue     0.77
#  8    Enterprise Value/EBITDA     3.00,
#  'DIVISLAB.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.22T
#  1           Enterprise Value  1.20T
#  2               Trailing P/E  57.23
#  3                Forward P/E    NaN
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)  16.69
#  6           Price/Book (mrq)  12.31
#  7   Enterprise Value/Revenue  16.43
#  8    Enterprise Value/EBITDA  37.91,
#  'DRREDDY.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  746.96B
#  1           Enterprise Value  752.66B
#  2               Trailing P/E    38.46
#  3                Forward P/E    22.42
#  4  PEG Ratio (5 yr expected)     1.25
#  5          Price/Sales (ttm)     3.68
#  6           Price/Book (mrq)     4.06
#  7   Enterprise Value/Revenue     3.70
#  8    Enterprise Value/EBITDA    17.79,
#  'EICHERMOT.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  685.04B
#  1           Enterprise Value  643.09B
#  2               Trailing P/E    41.09
#  3                Forward P/E    21.41
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     6.93
#  6           Price/Book (mrq)     5.94
#  7   Enterprise Value/Revenue     6.50
#  8    Enterprise Value/EBITDA    24.00,
#  'GILLETTE.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  177.91B
#  1           Enterprise Value  176.26B
#  2               Trailing P/E    59.90
#  3                Forward P/E      NaN
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     8.61
#  6           Price/Book (mrq)    22.55
#  7   Enterprise Value/Revenue     8.53
#  8    Enterprise Value/EBITDA    36.38,
#  'GOKEX.NS':                    Attribute  Recent
#  0      Market Cap (intraday)  16.02B
#  1           Enterprise Value  20.82B
#  2               Trailing P/E   25.56
#  3                Forward P/E     NaN
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)    0.98
#  6           Price/Book (mrq)    5.03
#  7   Enterprise Value/Revenue    1.66
#  8    Enterprise Value/EBITDA   16.02,
#  'GRASIM.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.12T
#  1           Enterprise Value  1.65T
#  2               Trailing P/E  18.43
#  3                Forward P/E    NaN
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.28
#  6           Price/Book (mrq)   1.59
#  7   Enterprise Value/Revenue   1.89
#  8    Enterprise Value/EBITDA   8.67,
#  'HCLTECH.NS':                    Attribute Recent
#  0      Market Cap (intraday)  3.18T
#  1           Enterprise Value  3.02T
#  2               Trailing P/E  27.56
#  3                Forward P/E  20.83
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   3.99
#  6           Price/Book (mrq)   5.24
#  7   Enterprise Value/Revenue   3.79
#  8    Enterprise Value/EBITDA  14.35,
#  'HDFC.NS':                    Attribute Recent
#  0      Market Cap (intraday)  5.01T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  24.23
#  3                Forward P/E  29.41
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.30
#  6           Price/Book (mrq)   3.06
#  7   Enterprise Value/Revenue   5.10
#  8    Enterprise Value/EBITDA    NaN,
#  'HDFCBANK.NS':                    Attribute Recent
#  0      Market Cap (intraday)  8.33T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  25.48
#  3                Forward P/E  19.12
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   8.87
#  6           Price/Book (mrq)   3.86
#  7   Enterprise Value/Revenue    NaN
#  8    Enterprise Value/EBITDA    NaN,
#  'HEROMOTOCO.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  492.01B
#  1           Enterprise Value  435.15B
#  2               Trailing P/E    16.96
#  3                Forward P/E    12.47
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     1.54
#  6           Price/Book (mrq)     3.13
#  7   Enterprise Value/Revenue     1.36
#  8    Enterprise Value/EBITDA     9.46,
#  'HINDALCO.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  939.97B
#  1           Enterprise Value    1.42T
#  2               Trailing P/E     8.81
#  3                Forward P/E     6.06
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     0.57
#  6           Price/Book (mrq)     1.32
#  7   Enterprise Value/Revenue     0.87
#  8    Enterprise Value/EBITDA     5.50,
#  'HINDUNILVR.NS':                    Attribute Recent
#  0      Market Cap (intraday)  5.50T
#  1           Enterprise Value  5.43T
#  2               Trailing P/E  65.49
#  3                Forward P/E  52.08
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)  11.08
#  6           Price/Book (mrq)  11.47
#  7   Enterprise Value/Revenue  10.94
#  8    Enterprise Value/EBITDA  43.84,
#  'IBREALEST.NS':                    Attribute  Recent
#  0      Market Cap (intraday)  76.40B
#  1           Enterprise Value  77.54B
#  2               Trailing P/E   41.04
#  3                Forward P/E     NaN
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)    3.23
#  6           Price/Book (mrq)    2.17
#  7   Enterprise Value/Revenue    3.34
#  8    Enterprise Value/EBITDA   17.46,
#  'ICICIBANK.NS':                    Attribute Recent
#  0      Market Cap (intraday)  5.23T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  24.98
#  3                Forward P/E  18.87
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.48
#  6           Price/Book (mrq)   3.10
#  7   Enterprise Value/Revenue    NaN
#  8    Enterprise Value/EBITDA    NaN,
#  'INDUSINDBK.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  708.89B
#  1           Enterprise Value      NaN
#  2               Trailing P/E    17.89
#  3                Forward P/E     9.49
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     3.42
#  6           Price/Book (mrq)     1.56
#  7   Enterprise Value/Revenue      NaN
#  8    Enterprise Value/EBITDA      NaN,
#  'INFY.NS':                    Attribute  Recent
#  0      Market Cap (intraday)   7.10T
#  1           Enterprise Value   6.92T
#  2               Trailing P/E   34.03
#  3                Forward P/E   27.40
#  4  PEG Ratio (5 yr expected)    2.28
#  5          Price/Sales (ttm)    6.39
#  6           Price/Book (mrq)    9.99
#  7   Enterprise Value/Revenue  464.06
#  8    Enterprise Value/EBITDA   1.58k,
#  'IOC.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.13T
#  1           Enterprise Value  2.08T
#  2               Trailing P/E   4.30
#  3                Forward P/E   6.68
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   0.24
#  6           Price/Book (mrq)   0.88
#  7   Enterprise Value/Revenue   0.45
#  8    Enterprise Value/EBITDA   3.99,
#  'ITC.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.69T
#  1           Enterprise Value  2.49T
#  2               Trailing P/E  18.78
#  3                Forward P/E  16.21
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.97
#  6           Price/Book (mrq)   4.41
#  7   Enterprise Value/Revenue   4.61
#  8    Enterprise Value/EBITDA  11.78,
#  'JSWSTEEL.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.56T
#  1           Enterprise Value  2.10T
#  2               Trailing P/E   7.81
#  3                Forward P/E   9.49
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.44
#  6           Price/Book (mrq)   2.56
#  7   Enterprise Value/Revenue   1.94
#  8    Enterprise Value/EBITDA   5.64,
#  'KOTAKBANK.NS':                    Attribute Recent
#  0      Market Cap (intraday)  3.81T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  38.28
#  3                Forward P/E  28.57
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   8.34
#  6           Price/Book (mrq)   4.25
#  7   Enterprise Value/Revenue    NaN
#  8    Enterprise Value/EBITDA    NaN,
#  'LT.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.53T
#  1           Enterprise Value  3.31T
#  2               Trailing P/E  29.20
#  3                Forward P/E  18.21
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.73
#  6           Price/Book (mrq)   3.31
#  7   Enterprise Value/Revenue   2.26
#  8    Enterprise Value/EBITDA  15.68,
#  'M&M.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.04T
#  1           Enterprise Value  1.63T
#  2               Trailing P/E  18.22
#  3                Forward P/E  17.79
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.12
#  6           Price/Book (mrq)   2.41
#  7   Enterprise Value/Revenue   1.97
#  8    Enterprise Value/EBITDA  10.41,
#  'MARUTI.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.18T
#  1           Enterprise Value  2.12T
#  2               Trailing P/E  51.85
#  3                Forward P/E  29.33
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   2.64
#  6           Price/Book (mrq)   4.17
#  7   Enterprise Value/Revenue   2.57
#  8    Enterprise Value/EBITDA  25.86,
#  'NESTLEIND.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.87T
#  1           Enterprise Value  1.84T
#  2               Trailing P/E  83.21
#  3                Forward P/E  69.93
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)  13.00
#  6           Price/Book (mrq)  83.35
#  7   Enterprise Value/Revenue  12.86
#  8    Enterprise Value/EBITDA  50.86,
#  'NTPC.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.21T
#  1           Enterprise Value  3.04T
#  2               Trailing P/E   9.06
#  3                Forward P/E   7.42
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.01
#  6           Price/Book (mrq)   0.93
#  7   Enterprise Value/Revenue   2.53
#  8    Enterprise Value/EBITDA   7.75,
#  'ONGC.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.83T
#  1           Enterprise Value  2.87T
#  2               Trailing P/E   5.10
#  3                Forward P/E    NaN
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   0.47
#  6           Price/Book (mrq)   0.74
#  7   Enterprise Value/Revenue   0.74
#  8    Enterprise Value/EBITDA   3.98,
#  'POWERGRID.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.41T
#  1           Enterprise Value  2.58T
#  2               Trailing P/E   8.74
#  3                Forward P/E  10.13
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   3.45
#  6           Price/Book (mrq)   1.82
#  7   Enterprise Value/Revenue   6.33
#  8    Enterprise Value/EBITDA   6.28,
#  'RELIANCE.NS':                    Attribute  Recent
#  0      Market Cap (intraday)  16.12T
#  1           Enterprise Value  16.56T
#  2               Trailing P/E   30.00
#  3                Forward P/E   22.52
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)    2.73
#  6           Price/Book (mrq)    2.17
#  7   Enterprise Value/Revenue    2.88
#  8    Enterprise Value/EBITDA   15.34,
#  'SBILIFE.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.17T
#  1           Enterprise Value  1.14T
#  2               Trailing P/E  94.49
#  3                Forward P/E  55.25
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.31
#  6           Price/Book (mrq)  10.69
#  7   Enterprise Value/Revenue   1.28
#  8    Enterprise Value/EBITDA    NaN,
#  'SBIN.NS':                    Attribute Recent
#  0      Market Cap (intraday)  4.22T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  14.74
#  3                Forward P/E  10.65
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.83
#  6           Price/Book (mrq)   1.44
#  7   Enterprise Value/Revenue    NaN
#  8    Enterprise Value/EBITDA    NaN,
#  'SHREECEM.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  924.24B
#  1           Enterprise Value  907.42B
#  2               Trailing P/E    35.24
#  3                Forward P/E    31.85
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     6.41
#  6           Price/Book (mrq)     5.63
#  7   Enterprise Value/Revenue     6.29
#  8    Enterprise Value/EBITDA    18.76,
#  'SUNPHARMA.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.80T
#  1           Enterprise Value  1.71T
#  2               Trailing P/E  29.03
#  3                Forward P/E  25.19
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   5.08
#  6           Price/Book (mrq)   3.64
#  7   Enterprise Value/Revenue   4.66
#  8    Enterprise Value/EBITDA  18.18,
#  'TATACONSUM.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  700.84B
#  1           Enterprise Value  683.27B
#  2               Trailing P/E    96.54
#  3                Forward P/E    53.48
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     5.78
#  6           Price/Book (mrq)     4.80
#  7   Enterprise Value/Revenue     5.63
#  8    Enterprise Value/EBITDA    45.14,
#  'TATAMOTORS.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.68T
#  1           Enterprise Value  2.45T
#  2               Trailing P/E    NaN
#  3                Forward P/E  29.41
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   0.68
#  6           Price/Book (mrq)   3.55
#  7   Enterprise Value/Revenue   0.99
#  8    Enterprise Value/EBITDA  12.63,
#  'TATASTEEL.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.39T
#  1           Enterprise Value  2.06T
#  2               Trailing P/E   4.25
#  3                Forward P/E   6.28
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   0.65
#  6           Price/Book (mrq)   1.52
#  7   Enterprise Value/Revenue   1.01
#  8    Enterprise Value/EBITDA   3.62,
#  'TCS.NS':                    Attribute  Recent
#  0      Market Cap (intraday)  13.47T
#  1           Enterprise Value  13.04T
#  2               Trailing P/E   36.97
#  3                Forward P/E   30.12
#  4  PEG Ratio (5 yr expected)    2.43
#  5          Price/Sales (ttm)    7.60
#  6           Price/Book (mrq)   13.89
#  7   Enterprise Value/Revenue    7.33
#  8    Enterprise Value/EBITDA   24.05,
#  'TECHM.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.56T
#  1           Enterprise Value  1.43T
#  2               Trailing P/E  27.93
#  3                Forward P/E  20.83
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   3.51
#  6           Price/Book (mrq)   6.19
#  7   Enterprise Value/Revenue   3.53
#  8    Enterprise Value/EBITDA  16.90,
#  'TITAN.NS':                    Attribute  Recent
#  0      Market Cap (intraday)   2.10T
#  1           Enterprise Value   2.14T
#  2               Trailing P/E  120.39
#  3                Forward P/E   75.76
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)    8.06
#  6           Price/Book (mrq)   27.05
#  7   Enterprise Value/Revenue    8.21
#  8    Enterprise Value/EBITDA   72.05,
#  'ULTRACEMCO.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.08T
#  1           Enterprise Value  2.14T
#  2               Trailing P/E  32.65
#  3                Forward P/E  21.98
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.16
#  6           Price/Book (mrq)   4.51
#  7   Enterprise Value/Revenue   4.28
#  8    Enterprise Value/EBITDA  15.93,
#  'UPL.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  547.48B
#  1           Enterprise Value  791.83B
#  2               Trailing P/E    18.14
#  3                Forward P/E      NaN
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     1.38
#  6           Price/Book (mrq)     2.53
#  7   Enterprise Value/Revenue     1.94
#  8    Enterprise Value/EBITDA     9.73,
#  'WIPRO.NS':                    Attribute Recent
#  0      Market Cap (intraday)  3.41T
#  1           Enterprise Value  3.23T
#  2               Trailing P/E  28.63
#  3                Forward P/E  24.57
#  4  PEG Ratio (5 yr expected)   1.34
#  5          Price/Sales (ttm)   4.96
#  6           Price/Book (mrq)   5.49
#  7   Enterprise Value/Revenue   4.62
#  8    Enterprise Value/EBITDA  20.69}

# %%
combined_stats = pd.concat(dow_stats)
combined_stats = combined_stats.reset_index()
combined_stats
# Out:
#            level_0  level_1                  Attribute Recent
# 0    ADANIPORTS.NS        0      Market Cap (intraday)  1.51T
# 1    ADANIPORTS.NS        1           Enterprise Value  1.83T
# 2    ADANIPORTS.NS        2               Trailing P/E  29.39
# 3    ADANIPORTS.NS        3                Forward P/E  19.57
# 4    ADANIPORTS.NS        4  PEG Ratio (5 yr expected)    NaN
# ..             ...      ...                        ...    ...
# 472       WIPRO.NS        4  PEG Ratio (5 yr expected)   1.34
# 473       WIPRO.NS        5          Price/Sales (ttm)   4.96
# 474       WIPRO.NS        6           Price/Book (mrq)   5.49
# 475       WIPRO.NS        7   Enterprise Value/Revenue   4.62
# 476       WIPRO.NS        8    Enterprise Value/EBITDA  20.69
#
# [477 rows x 4 columns]

# %%
del combined_stats["level_1"]
# update column names
combined_stats.columns = ["Ticker", "Attribute", "Recent"]
combined_stats
# Out:
#             Ticker                  Attribute Recent
# 0    ADANIPORTS.NS      Market Cap (intraday)  1.51T
# 1    ADANIPORTS.NS           Enterprise Value  1.83T
# 2    ADANIPORTS.NS               Trailing P/E  29.39
# 3    ADANIPORTS.NS                Forward P/E  19.57
# 4    ADANIPORTS.NS  PEG Ratio (5 yr expected)    NaN
# ..             ...                        ...    ...
# 472       WIPRO.NS  PEG Ratio (5 yr expected)   1.34
# 473       WIPRO.NS          Price/Sales (ttm)   4.96
# 474       WIPRO.NS           Price/Book (mrq)   5.49
# 475       WIPRO.NS   Enterprise Value/Revenue   4.62
# 476       WIPRO.NS    Enterprise Value/EBITDA  20.69
#
# [477 rows x 3 columns]

# %%
markcap = combined_stats[combined_stats["Attribute"]=="Market Cap (intraday)"].reset_index()
markcap
# Out:
#     index         Ticker              Attribute   Recent
# 0       0  ADANIPORTS.NS  Market Cap (intraday)    1.51T
# 1       9      ARVIND.NS  Market Cap (intraday)   29.24B
# 2      18  ASIANPAINT.NS  Market Cap (intraday)    2.98T
# 3      27    AXISBANK.NS  Market Cap (intraday)    2.06T
# 4      36  BAJAJ-AUTO.NS  Market Cap (intraday)  941.67B
# 5      45  BAJFINANCE.NS  Market Cap (intraday)    4.27T
# 6      54  BAJAJFINSV.NS  Market Cap (intraday)    2.69T
# 7      63  BHARTIARTL.NS  Market Cap (intraday)    4.21T
# 8      72        BPCL.NS  Market Cap (intraday)  837.11B
# 9      81   BRITANNIA.NS  Market Cap (intraday)  856.48B
# 10     90       CIPLA.NS  Market Cap (intraday)  724.41B
# 11     99   COALINDIA.NS  Market Cap (intraday)  984.50B
# 12    108    DIVISLAB.NS  Market Cap (intraday)    1.22T
# 13    117     DRREDDY.NS  Market Cap (intraday)  746.96B
# 14    126   EICHERMOT.NS  Market Cap (intraday)  685.04B
# 15    135    GILLETTE.NS  Market Cap (intraday)  177.91B
# 16    144       GOKEX.NS  Market Cap (intraday)   16.02B
# 17    153      GRASIM.NS  Market Cap (intraday)    1.12T
# 18    162     HCLTECH.NS  Market Cap (intraday)    3.18T
# 19    171        HDFC.NS  Market Cap (intraday)    5.01T
# 20    180    HDFCBANK.NS  Market Cap (intraday)    8.33T
# 21    189  HEROMOTOCO.NS  Market Cap (intraday)  492.01B
# 22    198    HINDALCO.NS  Market Cap (intraday)  939.97B
# 23    207  HINDUNILVR.NS  Market Cap (intraday)    5.50T
# 24    216   IBREALEST.NS  Market Cap (intraday)   76.40B
# 25    225   ICICIBANK.NS  Market Cap (intraday)    5.23T
# 26    234  INDUSINDBK.NS  Market Cap (intraday)  708.89B
# 27    243        INFY.NS  Market Cap (intraday)    7.10T
# 28    252         IOC.NS  Market Cap (intraday)    1.13T
# 29    261         ITC.NS  Market Cap (intraday)    2.69T
# 30    270    JSWSTEEL.NS  Market Cap (intraday)    1.56T
# 31    279   KOTAKBANK.NS  Market Cap (intraday)    3.81T
# 32    288          LT.NS  Market Cap (intraday)    2.53T
# 33    297         M&M.NS  Market Cap (intraday)    1.04T
# 34    306      MARUTI.NS  Market Cap (intraday)    2.18T
# 35    315   NESTLEIND.NS  Market Cap (intraday)    1.87T
# 36    324        NTPC.NS  Market Cap (intraday)    1.21T
# 37    333        ONGC.NS  Market Cap (intraday)    1.83T
# 38    342   POWERGRID.NS  Market Cap (intraday)    1.41T
# 39    351    RELIANCE.NS  Market Cap (intraday)   16.12T
# 40    360        SBIN.NS  Market Cap (intraday)    4.22T
# 41    369     SBILIFE.NS  Market Cap (intraday)    1.17T
# 42    378    SHREECEM.NS  Market Cap (intraday)  924.24B
# 43    387   SUNPHARMA.NS  Market Cap (intraday)    1.80T
# 44    396  TATAMOTORS.NS  Market Cap (intraday)    1.68T
# 45    405   TATASTEEL.NS  Market Cap (intraday)    1.39T
# 46    414         TCS.NS  Market Cap (intraday)   13.47T
# 47    423  TATACONSUM.NS  Market Cap (intraday)  700.84B
# 48    432       TECHM.NS  Market Cap (intraday)    1.56T
# 49    441       TITAN.NS  Market Cap (intraday)    2.10T
# 50    450  ULTRACEMCO.NS  Market Cap (intraday)    2.08T
# 51    459         UPL.NS  Market Cap (intraday)  547.48B
# 52    468       WIPRO.NS  Market Cap (intraday)    3.41T

# %%
del markcap["index"]

# %%
del markcap["Attribute"]
markcap.columns = ["Ticker", "Market Cap"]
markcap
# Out:
#            Ticker Market Cap
# 0   ADANIPORTS.NS      1.51T
# 1       ARVIND.NS     29.24B
# 2   ASIANPAINT.NS      2.98T
# 3     AXISBANK.NS      2.06T
# 4   BAJAJ-AUTO.NS    941.67B
# 5   BAJFINANCE.NS      4.27T
# 6   BAJAJFINSV.NS      2.69T
# 7   BHARTIARTL.NS      4.21T
# 8         BPCL.NS    837.11B
# 9    BRITANNIA.NS    856.48B
# 10       CIPLA.NS    724.41B
# 11   COALINDIA.NS    984.50B
# 12    DIVISLAB.NS      1.22T
# 13     DRREDDY.NS    746.96B
# 14   EICHERMOT.NS    685.04B
# 15    GILLETTE.NS    177.91B
# 16       GOKEX.NS     16.02B
# 17      GRASIM.NS      1.12T
# 18     HCLTECH.NS      3.18T
# 19        HDFC.NS      5.01T
# 20    HDFCBANK.NS      8.33T
# 21  HEROMOTOCO.NS    492.01B
# 22    HINDALCO.NS    939.97B
# 23  HINDUNILVR.NS      5.50T
# 24   IBREALEST.NS     76.40B
# 25   ICICIBANK.NS      5.23T
# 26  INDUSINDBK.NS    708.89B
# 27        INFY.NS      7.10T
# 28         IOC.NS      1.13T
# 29         ITC.NS      2.69T
# 30    JSWSTEEL.NS      1.56T
# 31   KOTAKBANK.NS      3.81T
# 32          LT.NS      2.53T
# 33         M&M.NS      1.04T
# 34      MARUTI.NS      2.18T
# 35   NESTLEIND.NS      1.87T
# 36        NTPC.NS      1.21T
# 37        ONGC.NS      1.83T
# 38   POWERGRID.NS      1.41T
# 39    RELIANCE.NS     16.12T
# 40        SBIN.NS      4.22T
# 41     SBILIFE.NS      1.17T
# 42    SHREECEM.NS    924.24B
# 43   SUNPHARMA.NS      1.80T
# 44  TATAMOTORS.NS      1.68T
# 45   TATASTEEL.NS      1.39T
# 46         TCS.NS     13.47T
# 47  TATACONSUM.NS    700.84B
# 48       TECHM.NS      1.56T
# 49       TITAN.NS      2.10T
# 50  ULTRACEMCO.NS      2.08T
# 51         UPL.NS    547.48B
# 52       WIPRO.NS      3.41T

# %%
markcap[["Market Cap"]] = markcap[["Market Cap"]].apply(lambda x: x.str.replace('.','', regex=True))
markcap[["Market Cap"]] = markcap[["Market Cap"]].apply(lambda x: x.str.replace('T','0000000000', regex=True))
markcap[["Market Cap"]] = markcap[["Market Cap"]].apply(lambda x: x.str.replace('B','0000000', regex=True))
markcap
# Out:
#            Ticker      Market Cap
# 0   ADANIPORTS.NS   1510000000000
# 1       ARVIND.NS     29240000000
# 2   ASIANPAINT.NS   2980000000000
# 3     AXISBANK.NS   2060000000000
# 4   BAJAJ-AUTO.NS    941670000000
# 5   BAJFINANCE.NS   4270000000000
# 6   BAJAJFINSV.NS   2690000000000
# 7   BHARTIARTL.NS   4210000000000
# 8         BPCL.NS    837110000000
# 9    BRITANNIA.NS    856480000000
# 10       CIPLA.NS    724410000000
# 11   COALINDIA.NS    984500000000
# 12    DIVISLAB.NS   1220000000000
# 13     DRREDDY.NS    746960000000
# 14   EICHERMOT.NS    685040000000
# 15    GILLETTE.NS    177910000000
# 16       GOKEX.NS     16020000000
# 17      GRASIM.NS   1120000000000
# 18     HCLTECH.NS   3180000000000
# 19        HDFC.NS   5010000000000
# 20    HDFCBANK.NS   8330000000000
# 21  HEROMOTOCO.NS    492010000000
# 22    HINDALCO.NS    939970000000
# 23  HINDUNILVR.NS   5500000000000
# 24   IBREALEST.NS     76400000000
# 25   ICICIBANK.NS   5230000000000
# 26  INDUSINDBK.NS    708890000000
# 27        INFY.NS   7100000000000
# 28         IOC.NS   1130000000000
# 29         ITC.NS   2690000000000
# 30    JSWSTEEL.NS   1560000000000
# 31   KOTAKBANK.NS   3810000000000
# 32          LT.NS   2530000000000
# 33         M&M.NS   1040000000000
# 34      MARUTI.NS   2180000000000
# 35   NESTLEIND.NS   1870000000000
# 36        NTPC.NS   1210000000000
# 37        ONGC.NS   1830000000000
# 38   POWERGRID.NS   1410000000000
# 39    RELIANCE.NS  16120000000000
# 40        SBIN.NS   4220000000000
# 41     SBILIFE.NS   1170000000000
# 42    SHREECEM.NS    924240000000
# 43   SUNPHARMA.NS   1800000000000
# 44  TATAMOTORS.NS   1680000000000
# 45   TATASTEEL.NS   1390000000000
# 46         TCS.NS  13470000000000
# 47  TATACONSUM.NS    700840000000
# 48       TECHM.NS   1560000000000
# 49       TITAN.NS   2100000000000
# 50  ULTRACEMCO.NS   2080000000000
# 51         UPL.NS    547480000000
# 52       WIPRO.NS   3410000000000

# %%
markcap[["Market Cap"]] = markcap[["Market Cap"]].apply(pd.to_numeric)
markcap
# Out:
#            Ticker      Market Cap
# 0   ADANIPORTS.NS   1510000000000
# 1       ARVIND.NS     29240000000
# 2   ASIANPAINT.NS   2980000000000
# 3     AXISBANK.NS   2060000000000
# 4   BAJAJ-AUTO.NS    941670000000
# 5   BAJFINANCE.NS   4270000000000
# 6   BAJAJFINSV.NS   2690000000000
# 7   BHARTIARTL.NS   4210000000000
# 8         BPCL.NS    837110000000
# 9    BRITANNIA.NS    856480000000
# 10       CIPLA.NS    724410000000
# 11   COALINDIA.NS    984500000000
# 12    DIVISLAB.NS   1220000000000
# 13     DRREDDY.NS    746960000000
# 14   EICHERMOT.NS    685040000000
# 15    GILLETTE.NS    177910000000
# 16       GOKEX.NS     16020000000
# 17      GRASIM.NS   1120000000000
# 18     HCLTECH.NS   3180000000000
# 19        HDFC.NS   5010000000000
# 20    HDFCBANK.NS   8330000000000
# 21  HEROMOTOCO.NS    492010000000
# 22    HINDALCO.NS    939970000000
# 23  HINDUNILVR.NS   5500000000000
# 24   IBREALEST.NS     76400000000
# 25   ICICIBANK.NS   5230000000000
# 26  INDUSINDBK.NS    708890000000
# 27        INFY.NS   7100000000000
# 28         IOC.NS   1130000000000
# 29         ITC.NS   2690000000000
# 30    JSWSTEEL.NS   1560000000000
# 31   KOTAKBANK.NS   3810000000000
# 32          LT.NS   2530000000000
# 33         M&M.NS   1040000000000
# 34      MARUTI.NS   2180000000000
# 35   NESTLEIND.NS   1870000000000
# 36        NTPC.NS   1210000000000
# 37        ONGC.NS   1830000000000
# 38   POWERGRID.NS   1410000000000
# 39    RELIANCE.NS  16120000000000
# 40        SBIN.NS   4220000000000
# 41     SBILIFE.NS   1170000000000
# 42    SHREECEM.NS    924240000000
# 43   SUNPHARMA.NS   1800000000000
# 44  TATAMOTORS.NS   1680000000000
# 45   TATASTEEL.NS   1390000000000
# 46         TCS.NS  13470000000000
# 47  TATACONSUM.NS    700840000000
# 48       TECHM.NS   1560000000000
# 49       TITAN.NS   2100000000000
# 50  ULTRACEMCO.NS   2080000000000
# 51         UPL.NS    547480000000
# 52       WIPRO.NS   3410000000000

# %%
markcap['Class'] = np.where(markcap['Market Cap'] >= 200000000000, 'Large-cap', 'Mid-cap')
markcap
# Out:
#            Ticker      Market Cap      Class
# 0   ADANIPORTS.NS   1510000000000  Large-cap
# 1       ARVIND.NS     29240000000    Mid-cap
# 2   ASIANPAINT.NS   2980000000000  Large-cap
# 3     AXISBANK.NS   2060000000000  Large-cap
# 4   BAJAJ-AUTO.NS    941670000000  Large-cap
# 5   BAJFINANCE.NS   4270000000000  Large-cap
# 6   BAJAJFINSV.NS   2690000000000  Large-cap
# 7   BHARTIARTL.NS   4210000000000  Large-cap
# 8         BPCL.NS    837110000000  Large-cap
# 9    BRITANNIA.NS    856480000000  Large-cap
# 10       CIPLA.NS    724410000000  Large-cap
# 11   COALINDIA.NS    984500000000  Large-cap
# 12    DIVISLAB.NS   1220000000000  Large-cap
# 13     DRREDDY.NS    746960000000  Large-cap
# 14   EICHERMOT.NS    685040000000  Large-cap
# 15    GILLETTE.NS    177910000000    Mid-cap
# 16       GOKEX.NS     16020000000    Mid-cap
# 17      GRASIM.NS   1120000000000  Large-cap
# 18     HCLTECH.NS   3180000000000  Large-cap
# 19        HDFC.NS   5010000000000  Large-cap
# 20    HDFCBANK.NS   8330000000000  Large-cap
# 21  HEROMOTOCO.NS    492010000000  Large-cap
# 22    HINDALCO.NS    939970000000  Large-cap
# 23  HINDUNILVR.NS   5500000000000  Large-cap
# 24   IBREALEST.NS     76400000000    Mid-cap
# 25   ICICIBANK.NS   5230000000000  Large-cap
# 26  INDUSINDBK.NS    708890000000  Large-cap
# 27        INFY.NS   7100000000000  Large-cap
# 28         IOC.NS   1130000000000  Large-cap
# 29         ITC.NS   2690000000000  Large-cap
# 30    JSWSTEEL.NS   1560000000000  Large-cap
# 31   KOTAKBANK.NS   3810000000000  Large-cap
# 32          LT.NS   2530000000000  Large-cap
# 33         M&M.NS   1040000000000  Large-cap
# 34      MARUTI.NS   2180000000000  Large-cap
# 35   NESTLEIND.NS   1870000000000  Large-cap
# 36        NTPC.NS   1210000000000  Large-cap
# 37        ONGC.NS   1830000000000  Large-cap
# 38   POWERGRID.NS   1410000000000  Large-cap
# 39    RELIANCE.NS  16120000000000  Large-cap
# 40        SBIN.NS   4220000000000  Large-cap
# 41     SBILIFE.NS   1170000000000  Large-cap
# 42    SHREECEM.NS    924240000000  Large-cap
# 43   SUNPHARMA.NS   1800000000000  Large-cap
# 44  TATAMOTORS.NS   1680000000000  Large-cap
# 45   TATASTEEL.NS   1390000000000  Large-cap
# 46         TCS.NS  13470000000000  Large-cap
# 47  TATACONSUM.NS    700840000000  Large-cap
# 48       TECHM.NS   1560000000000  Large-cap
# 49       TITAN.NS   2100000000000  Large-cap
# 50  ULTRACEMCO.NS   2080000000000  Large-cap
# 51         UPL.NS    547480000000  Large-cap
# 52       WIPRO.NS   3410000000000  Large-cap
